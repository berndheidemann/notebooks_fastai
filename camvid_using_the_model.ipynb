# %%
# !gdown https://drive.google.com/uc?id=1cT-M3dr2ZZXkYrVRVAkMALmU9BcxvYbr
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cT-M3dr2ZZXkYrVRVAkMALmU9BcxvYbr
# To: /content/camvid.model.pkl
# 229MB [00:08, 28.6MB/s]

# %%
from fastai.imports import *
from fastai.vision import *
# %matplotlib inline

# %%
def acc_camvid(input, target):
    pass
  
learner=load_learner(path=".", fname="camvid.model.pkl")

# %%
from PIL import Image
import requests
from io import BytesIO


def prepareImage(url):
  response = requests.get(url)
  img = Image.open(BytesIO(response.content))
  img=img.resize((480, 360))
  img.save("to_process.jpg")
 
prepareImage("https://upload.wikimedia.org/wikipedia/commons/thumb/1/1d/Berlin-Friedrichshain_Stra%C3%9Fe_der_Pariser_Kommune.jpg/1200px-Berlin-Friedrichshain_Stra%C3%9Fe_der_Pariser_Kommune.jpg")

# %%
image=open_image("to_process.jpg")

# %%
image
# Out:
# Image (3, 360, 480)

# %%
predicted=learner.predict(image)

# %%
predicted[0].show(figsize=(12,12))

# %%
image.show(y=predicted[0], title='masked', figsize=(15, 15))
